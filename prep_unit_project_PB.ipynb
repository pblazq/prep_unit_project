# %%
#read the dataset with sqlite3
import sqlite3
import pandas as pd
conn = sqlite3.connect('longley.db')
df = pd.read_sql_query("SELECT * FROM longley", conn)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\envs\cla\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such table: longley
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[1], line 5
#       1 #read the dataset with sqlite3
#       2 import sqlite3
#       3 import pandas as pd
#       4 conn = sqlite3.connect('longley.db')
# ----> 5 df = pd.read_sql_query("SELECT * FROM longley", conn)
#       6 print(df.head())
#
# File c:\envs\cla\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
# ...
